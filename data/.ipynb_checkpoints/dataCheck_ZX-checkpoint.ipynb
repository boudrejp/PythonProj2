# %%
import csv
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime

list_time = []
list_search = []
with open('GoogleTrends_JBush.csv','rt',encoding='utf-8') as CSVread:
    for i in range(3):
        next(CSVread)
    CSV_read = csv.reader(CSVread)
    for month,search in CSV_read:
        if search == '<1':
            search = 0
        list_time.append(datetime.strptime(month,'%Y-%m'))
        list_search.append(float(search))
#     list_data = [dict(row) for row in CSV_read]
# list_data
series_data = pd.DataFrame({'month':list_time,
                            'searches':list_search})
plot1 = plt.plot_date(series_data['month'],series_data['searches'],fmt='-',label='Google Search')


#Import the lyrics mentions data for Trump
list_year = []
list_mention = []
with open('HipHopLyrics.csv','rt',encoding='utf-8') as CSVread:
    has_header = csv.Sniffer().has_header(CSVread.read(1024))
    CSVread.seek(0)
    CSV_read1 = csv.DictReader(CSVread,fieldnames=['id','candidate','song'
                                                  ,'artist','sentiment',
                                                  'theme','album_release_date',
                                                  'line','url']) 
    if has_header:
        next(CSV_read1)
    list_data = [dict(row) for row in CSV_read1]
# total mentions
list_year = [i['album_release_date'] for i in list_data]
list_mentions = [i['candidate'] for i in list_data]

df_lyrics = pd.DataFrame(list_data)
print(df_lyrics.columns)
df_lyrics_check = df_lyrics.copy()
df_lyrics_check['album_release_date'] = pd.to_datetime(df_lyrics_check['album_release_date'])
df_lyrics_check = df_lyrics_check[df_lyrics_check.candidate == 'Jeb Bush'][df_lyrics_check.album_release_date<'2006'][df_lyrics_check.album_release_date>'2004']
print(df_lyrics_check)
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Jeb Bush'].groupby('album_release_date').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['album_release_date'] = pd.to_datetime(df_lyrics1['album_release_date'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('album_release_date').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['album_release_date'] = pd.to_datetime(df_lyrics2['album_release_date'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('album_release_date').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['album_release_date'] = pd.to_datetime(df_lyrics3['album_release_date'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('album_release_date').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['album_release_date'] = pd.to_datetime(df_lyrics4['album_release_date'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])
#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']*100/val_max
df_lyrics2['count'] = df_lyrics2['count']*100/val_max
df_lyrics3['count'] = df_lyrics3['count']*100/val_max
df_lyrics4['count'] = df_lyrics4['count']*100/val_max
plot1 = plt.plot(df_lyrics1['album_release_date'],df_lyrics1['count'],label='total lyrics mentions',marker='o')
plot1 = plt.plot(df_lyrics2['album_release_date'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['album_release_date'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['album_release_date'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('mentions/searches')
plt.title('Jeb Bush: lyrics mentions vs. internet searches')
plt.xlim(datetime(1989,1,1),datetime(2017,1,1))
plt.ylim(0,120)
plt.savefig('Jeb Bush comparison plot.png')
# Out:
# Index(['album_release_date', 'artist', 'candidate', 'id', 'line', 'sentiment',
#        'song', 'theme', 'url'],
#       dtype='object')
#    album_release_date      artist candidate  id  \
# 7          2005-01-01  Macklemore  Jeb Bush   8
# 9          2005-01-01         RZA  Jeb Bush  10
# 10         2005-01-01        Zeno  Jeb Bush  11
#
#                                                  line sentiment  \
# 7                Way to go Jeb, really great strategy  negative
# 9                  Bobby got Bush like George and Jeb   neutral
# 10  I was promised eternal life from the beginning...   neutral
#
#                song      theme  \
# 7         Bush Song  political
# 9   Chamber of Fear   personal
# 10      Tell Me Why   personal
#
#                                                  url
# 7      http://genius.com/Macklemore-bush-song-lyrics
# 9       http://genius.com/Rza-chamber-of-fear-lyrics
# 10  http://genius.com/Vanilla-ice-tell-me-why-lyrics
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
import csv
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime

list_time = []
list_search = []
with open('GoogleTrends_HClinton.csv','rt',encoding='utf-8') as CSVread:
    for i in range(3):
        next(CSVread)
    CSV_read = csv.reader(CSVread)
    for month,search in CSV_read:
        if search == '<1':
            search = 0
        list_time.append(datetime.strptime(month,'%Y-%m'))
        list_search.append(float(search))
#     list_data = [dict(row) for row in CSV_read]
# list_data
series_data = pd.DataFrame({'month':list_time,
                            'searches':list_search})
plot1 = plt.plot_date(series_data['month'],series_data['searches'],fmt='-',label='Google Search')


#Import the lyrics mentions data for Trump
list_year = []
list_mention = []
with open('HipHopLyrics.csv','rt',encoding='utf-8') as CSVread:
    has_header = csv.Sniffer().has_header(CSVread.read(1024))
    CSVread.seek(0)
    CSV_read1 = csv.DictReader(CSVread,fieldnames=['id','candidate','song'
                                                  ,'artist','sentiment',
                                                  'theme','album_release_date',
                                                  'line','url']) 
    if has_header:
        next(CSV_read1)
    list_data = [dict(row) for row in CSV_read1]
# total mentions
list_year = [i['album_release_date'] for i in list_data]
list_mentions = [i['candidate'] for i in list_data]
df_lyrics = pd.DataFrame(list_data)
#data check
print(df_lyrics.columns)
df_lyrics_check = df_lyrics.copy()
df_lyrics_check['album_release_date'] = pd.to_datetime(df_lyrics_check['album_release_date'])
df_lyrics_check = df_lyrics_check[df_lyrics_check.candidate == 'Hillary Clinton'][df_lyrics_check.album_release_date>'2007'][df_lyrics_check.album_release_date<'2009']
print(df_lyrics_check)

df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton'].groupby('album_release_date').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['album_release_date'] = pd.to_datetime(df_lyrics1['album_release_date'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('album_release_date').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['album_release_date'] = pd.to_datetime(df_lyrics2['album_release_date'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('album_release_date').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['album_release_date'] = pd.to_datetime(df_lyrics3['album_release_date'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('album_release_date').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['album_release_date'] = pd.to_datetime(df_lyrics4['album_release_date'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])
#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']*100/val_max
df_lyrics2['count'] = df_lyrics2['count']*100/val_max
df_lyrics3['count'] = df_lyrics3['count']*100/val_max
df_lyrics4['count'] = df_lyrics4['count']*100/val_max
plot1 = plt.plot(df_lyrics1['album_release_date'],df_lyrics1['count'],label='total lyrics mentions')
plot1 = plt.plot(df_lyrics2['album_release_date'],df_lyrics2['count'],label='negative lyrics mentions', linestyle='--')
plot1 = plt.plot(df_lyrics3['album_release_date'],df_lyrics3['count'],label='positive lyrics mentions', linestyle='-.')
plot1 = plt.plot(df_lyrics4['album_release_date'],df_lyrics4['count'],label='neutral lyrics mentions', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('mentions/searches')
plt.title('Hillary Clinton: lyrics mentions vs. internet searches')
plt.xlim(datetime(2005,1,1),datetime(2009,1,1))
plt.ylim(0,120)
plt.figure(figsize=(20,5))
# Out:
# Index(['album_release_date', 'artist', 'candidate', 'id', 'line', 'sentiment',
#        'song', 'theme', 'url'],
#       dtype='object')
#     album_release_date               artist        candidate   id  \
# 27          2008-01-01             The Game  Hillary Clinton   28
# 33          2008-01-01              Big Boi  Hillary Clinton   34
# 35          2008-01-01     Charles Hamilton  Hillary Clinton   36
# 45          2008-01-01             Fabolous  Hillary Clinton   46
# 55          2008-01-01             Ice Cube  Hillary Clinton   56
# 58          2008-01-01            Jae Millz  Hillary Clinton   59
# 62          2008-01-01                Jeezy  Hillary Clinton   63
# 64          2008-01-01          Killer Mike  Hillary Clinton   65
# 67          2008-01-01         Kutt Calhoun  Hillary Clinton   68
# 69          2008-01-01            Lil Wayne  Hillary Clinton   70
# 70          2008-01-01             Ludacris  Hillary Clinton   71
# 71          2008-01-01             Ludacris  Hillary Clinton   72
# 76          2008-01-01         Mickey Factz  Hillary Clinton   77
# 81          2008-01-01              Papoose  Hillary Clinton   82
# 86          2008-01-01  R.A. the Rugged Man  Hillary Clinton   87
# 94          2008-01-01        Royce Da 5'9"  Hillary Clinton   95
# 101         2008-01-01      T.H.U.G. Angelz  Hillary Clinton  103
#
#                                                   line sentiment  \
# 27   If Dr. King marched today would Bill Gates mar...   neutral
# 33                Energy like Bill and Hillary Clinton   neutral
# 35   You more like Hillary / Only in it cuz you use...  negative
# 45      Hillary, Bill Clin--Fuck it. They don't get it  negative
# 55   Never put your trust in Hillary Rodham / Cause...  negative
# 58           Straight Osam 'em, treat 'em like Hillary   neutral
# 62               It goes Hillary Clinton, Barack Obama   neutral
# 64   Or you a dirty n---- working for a fucking Cli...  negative
# 67   Look at Hillary Clinton when she speak / Looki...  negative
# 69      And when I'm at the bottom, she Hillary Rodham   neutral
# 70   Hillary's still with Bill Clinton, how do they...  negative
# 71   Hillary hated on you so that {censored} bitch ...  negative
# 76   Nothing against Hilary Clinton / But Obama's a...   neutral
# 81   More like Obama versus Hillary, nothing / A in...  negative
# 86   Sewed Hillary Clinton's mouth, and that's afte...  negative
# 94   This industry is Hillary Clinton literally, li...   neutral
# 101  It's like we paying them rent to live inside a...  negative
#
#                                   song      theme  \
# 27                  Letter to the King  political
# 33                              Energy   personal
# 35                        Unapologetic  political
# 45                             A Milli   personal
# 55                          Stand Tall        N/A
# 58            Holla at a Playa (Remix)  political
# 62             I Luv Your Girl (Remix)        N/A
# 64                            Pressure  political
# 67                       Smilin' Faces        N/A
# 69                            Lollipop   personal
# 70                 Let's Stay Together   personal
# 71   Politics as Usual (Obama Is Here)  political
# 76                             Vietnam  political
# 81                 Shoot Me a Fair One  political
# 86                      Fall Down Brew        N/A
# 94                    I'm Me Freestyle        N/A
# 101                          Gang Love  political
#
#                                                    url
# 27   http://genius.com/The-game-letter-to-the-king-...
# 33   http://genius.com/Raheem-devaughn-energy-feat-...
# 35   http://genius.com/Charles-hamilton-unapologeti...
# 45           http://genius.com/Fabolous-a-milli-lyrics
# 55        http://genius.com/Ice-cube-stand-tall-lyrics
# 58   http://genius.com/Jae-millz-holla-at-a-playa-r...
# 62   http://genius.com/The-dream-i-luv-your-girl-re...
# 64       http://genius.com/Killer-mike-pressure-lyrics
# 67   http://genius.com/Kutt-calhoun-smilin-faces-ly...
# 69         http://genius.com/Lil-wayne-lollipop-lyrics
# 70   http://genius.com/Ludacris-lets-stay-together-...
# 71   http://genius.com/Ludacris-politics-as-usual-o...
# 76       http://genius.com/Mickey-factz-vietnam-lyrics
# 81   http://genius.com/Papoose-shoot-me-a-fair-one-...
# 86   http://genius.com/Chief-chinchilla-aka-j-zone-...
# 94   http://genius.com/Royce-da-59-im-me-freestyle-...
# 101     http://genius.com/Thug-angelz-gang-love-lyrics
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
