# %%
import csv
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv('HipHopLyrics_corrected.csv', encoding="ISO-8859-1")
# df['month'] = "1"
# df['day'] = "1"
df['corrected_release_year'] = df['corrected_release_year'].astype(str)
# df['newdates'] = df.apply(lambda x: ','.join(x.dropna().values.tolist()),axis=1)
df['corrected_release_year'] = pd.to_datetime(df['corrected_release_year'])

df.head()
# df.columns
# Out:
#    id      candidate             song       artist sentiment      theme  \
# 0   1  Mike Huckabee  None Shall Pass   Aesop Rock   neutral        NaN
# 1   2  Mike Huckabee        Wellstone    Soul Khan  negative        NaN
# 2   3       Jeb Bush              Awe   Dez & Nobs   neutral        NaN
# 3   4       Jeb Bush        The Truth     Diabolic  negative  political
# 4   5       Jeb Bush        Money Man  Gorilla Zoe  negative   personal
#
#    album_release_date                                               line  \
# 0                2011  Wither by the watering hole, Border patrol / W...
# 1                2012  Might find the door but never touch the key / ...
# 2                2006         I heard Jeb Bush looking for a (inaudible)
# 3                2006  What you heard before ain't as big of a lesson...
# 4                2007  I'm comin back from Florida / Wit Jeb Bush and...
#
#                                                  url  song_views release_date  \
# 0  http://genius.com/Aesop-rock-none-shall-pass-l...      329759      8/28/07
# 1       http://genius.com/Soul-khan-wellstone-lyrics        5847      3/12/12
# 2          http://genius.com/Dez-and-nobs-awe-lyrics         133      5/15/06
# 3        http://genius.com/Diabolic-the-truth-lyrics        2679          NaN
# 4     http://genius.com/Gorilla-zoe-money-man-lyrics         816          NaN
#
#   years_match corrected_release_year  \
# 0       False             2007-01-01
# 1        True             2012-01-01
# 2        True             2006-01-01
# 3         NaN             2006-01-01
# 4         NaN             2007-01-01
#
#                                         split_lyrics
# 0  ['Wither', 'by', 'the', 'watering', 'hole', 'B...
# 1  ['Might', 'find', 'the', 'door', 'but', 'never...
# 2  ['I', 'heard', 'Jeb', 'Bush', 'looking', 'for'...
# 3  ['What', 'you', 'heard', 'before', "ain't", 'a...
# 4  ["I'm", 'comin', 'back', 'from', 'Florida', '/...

# %%
import csv
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt

df_lyrics = pd.read_csv('HipHopLyrics_corrected.csv', encoding="ISO-8859-1")
df_lyrics['corrected_release_year'] = df_lyrics['corrected_release_year'].astype(str)

# df_lyrics = pd.DataFrame(list_data)
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Donald Trump'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

#print(df_lyrics1.head())

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Donald Trump']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Donald Trump']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Donald Trump']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Donald Trump: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,50)
plt.savefig('Donald Trump lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Ben Carson'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Ben Carson']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Ben Carson']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Ben Carson']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Ben Carson: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,2)
plt.savefig('Ben Carson lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Bernie Sanders'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Bernie Sanders']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Bernie Sanders']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Bernie Sanders']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Bernie Sanders: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,3)
plt.savefig('Bernie Sanders lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Chris Christie'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Chris Christie']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Chris Christie']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Chris Christie']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Chris Christie: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,3)
plt.savefig('Chris Christie lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Hillary Clinton']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Hillary Clinton: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,20)
plt.savefig('Hillary Clinton lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Jeb Bush'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Jeb Bush']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Jeb Bush: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,5)
plt.savefig('Jeb Bush lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Mike Huckabee'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Mike Huckabee']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Mike Huckabee']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Mike Huckabee']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Mike Huckabee: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,5)
plt.savefig('Mike Huckabee lyrics mentions history plot.png')

# %%
df_lyrics['count'] = 1
df_lyrics1 = df_lyrics[df_lyrics.candidate == 'Ted Cruz'].groupby('corrected_release_year').sum()
df_lyrics1.reset_index(level=0,inplace=True)
df_lyrics1['corrected_release_year'] = pd.to_datetime(df_lyrics1['corrected_release_year'])

# negative mentions
df_lyrics2 = df_lyrics[df_lyrics.candidate == 'Ted Cruz']
df_lyrics2 = df_lyrics2[df_lyrics2.sentiment == 'negative'].groupby('corrected_release_year').sum()
df_lyrics2.reset_index(level=0,inplace=True)
df_lyrics2['corrected_release_year'] = pd.to_datetime(df_lyrics2['corrected_release_year'])

# positive mentions
df_lyrics3 = df_lyrics[df_lyrics.candidate == 'Ted Cruz']
df_lyrics3 = df_lyrics3[df_lyrics3.sentiment == 'positive'].groupby('corrected_release_year').sum()
df_lyrics3.reset_index(level=0,inplace=True)
df_lyrics3['corrected_release_year'] = pd.to_datetime(df_lyrics3['corrected_release_year'])

# neutral mentions
df_lyrics4 = df_lyrics[df_lyrics.candidate == 'Ted Cruz']
df_lyrics4 = df_lyrics4[df_lyrics4.sentiment == 'neutral'].groupby('corrected_release_year').sum()
df_lyrics4.reset_index(level=0,inplace=True)
df_lyrics4['corrected_release_year'] = pd.to_datetime(df_lyrics4['corrected_release_year'])
# print(df_lyrics4)
# print(df_lyrics1['album_release_date'])
# print(df_lyrics1['count'])

#scaling
val_max = df_lyrics1['count'].max()
df_lyrics1['count'] = df_lyrics1['count']
df_lyrics2['count'] = df_lyrics2['count']
df_lyrics3['count'] = df_lyrics3['count']
df_lyrics4['count'] = df_lyrics4['count']
plot1 = plt.plot(df_lyrics1['corrected_release_year'],df_lyrics1['count'],label='total lyrics mentions', marker='o')
plot1 = plt.plot(df_lyrics2['corrected_release_year'],df_lyrics2['count'],label='negative lyrics mentions', marker='+', linestyle='--')
plot1 = plt.plot(df_lyrics3['corrected_release_year'],df_lyrics3['count'],label='positive lyrics mentions', marker='p', linestyle='-.')
plot1 = plt.plot(df_lyrics4['corrected_release_year'],df_lyrics4['count'],label='neutral lyrics mentions', marker='d', linestyle=':')


plt.legend()
plt.xlabel('dates')
plt.ylabel('No. of Mentions')
plt.title('Ted Cruz: lyrics mentions')
plt.xlim(datetime.date(1989,1,1),datetime.date(2017,1,1))
plt.ylim(0,5)
plt.savefig('Ted Cruz lyrics mentions history plot.png')
